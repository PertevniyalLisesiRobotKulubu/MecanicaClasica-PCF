# %%
from __future__ import print_function
import numpy as np
from numpy import arccos,sin, cos, pi, array, sqrt
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
#Plot of contact points for disks in an inclined plane

#axe length
l= 10

#starting point in X
X0 = 5

#starting point in Y
Y0 = 5

#inclination angle
alpha = 30

#gravity
g = 9.8

#angular velocity
omega = 10

#time
t = np.linspace(0,5,1000)

xi_1 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) + (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 
xi_2 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) - (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 


plt.plot(t,xi_1,label=r'$\xi_1$')
plt.plot(t,xi_2,label=r'$\xi_2$')
plt.legend(loc=4)
plt.ylabel(r'$\xi_i$', fontsize=30)
plt.xlabel(r'$t$',fontsize=30)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Plot of contact points for disks in an inclined plane

#axe length
l= 10

#starting point in X
X0 = 10

#starting point in Y
Y0 = 5

#inclination angle
alpha = 10

#gravity
g = 9.8

#angular velocity
omega = 10

#time
t = np.linspace(0,5,1000)

xi_1 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) + (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 
xi_2 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) - (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 


plt.plot(t,xi_1,label=r'$\xi_1$')
plt.plot(t,xi_2,label=r'$\xi_2$')
plt.legend(loc=4)
plt.ylabel(r'$\xi_i$', fontsize=30)
plt.xlabel(r'$t$',fontsize=30)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Plot of contact points for disks in an inclined plane

#axe length
l= 50

#starting point in X
X0 = 5

#starting point in Y
Y0 = 5

#inclination angle
alpha = 50

#gravity
g = 9.8

#angular velocity
omega = 10

#time
t = np.linspace(0,5,1000)

xi_1 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) + (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 
xi_2 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) - (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 


plt.plot(t,xi_1,label=r'$\xi_1$')
plt.plot(t,xi_2,label=r'$\xi_2$')
plt.legend(loc=4)
plt.ylabel(r'$\xi_i$', fontsize=30)
plt.xlabel(r'$t$',fontsize=30)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Plot of contact points for disks in an inclined plane

#axe length
l= 10

#starting point in X
X0 = 5

#starting point in Y
Y0 = 5

#inclination angle
alpha = 30

#gravity
g = 9.8

#angular velocity
omega = 10

#time
t = np.linspace(0,10,1000)

xi_1 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) + (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 
xi_2 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) - (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 


plt.plot(t,xi_1,label=r'$\xi_1$')
plt.plot(t,xi_2,label=r'$\xi_2$')
plt.legend(loc=4)
plt.ylabel(r'$\xi_i$', fontsize=30)
plt.xlabel(r'$t$',fontsize=30)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Plot of contact points for disks in an inclined plane

#axe length
l= 10

#starting point in X
X0 = 5

#starting point in Y
Y0 = 5

#inclination angle
alpha = 30

#gravity
g = 9.8

#angular velocity
omega = 10

#time
t = np.linspace(0,10,1000)

xi_1 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) + (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 
xi_2 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) - (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 


plt.plot(xi_2,xi_1)
plt.ylabel(r'$\xi_1$', fontsize=30)
plt.xlabel(r'$\xi_2$',fontsize=30)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Plot of contact points for disks in an inclined plane

#axe length
l= 10

#starting point in X
X0 = 5

#starting point in Y
Y0 = 5

#inclination angle
alpha = 10

#gravity
g = 9.8

#angular velocity
omega = 10

#time
t = np.linspace(0,10,1000)

xi_1 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) + (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 
xi_2 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) - (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 


plt.plot(xi_2,xi_1)
plt.ylabel(r'$\xi_1$', fontsize=30)
plt.xlabel(r'$\xi_2$',fontsize=30)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Plot of contact points for disks in an inclined plane

#axe length
l= 50

#starting point in X
X0 = 5

#starting point in Y
Y0 = 5

#inclination angle
alpha = 60

#gravity
g = 9.8

#angular velocity
omega = 10

#time
t = np.linspace(0,10,1000)

xi_1 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) + (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 
xi_2 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) - (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 


plt.plot(xi_2,xi_1)
plt.ylabel(r'$\xi_1$', fontsize=30)
plt.xlabel(r'$\xi_2$',fontsize=30)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Plot of contact points for disks in an inclined plane

#axe length
l= 2

#starting point in X
X0 = 5

#starting point in Y
Y0 = 5

#inclination angle
alpha = 45

#gravity
g = 9.8

#angular velocity
omega = 10

#time
t = np.linspace(0,10,1000)

xi_1 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) + (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 
xi_2 = (g*sin(alpha))/(4*omega)*(t*(sin(2*omega*t))/(2*omega)) + (g*sin(alpha)*(cos(omega*t))**2) - (l/2)*(cos(omega*t)+sin(omega*t)) + X0 + Y0 


plt.plot(xi_2,xi_1)
plt.ylabel(r'$\xi_1$', fontsize=30)
plt.xlabel(r'$\xi_2$',fontsize=30)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
